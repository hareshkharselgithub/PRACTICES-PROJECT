# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/dataset3/main/Salaries.csv')

# %%
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
import seaborn as sns
sns.scatterplot(x='rank',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %%
sns.scatterplot(x='discipline',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='salary'>

# %%
sns.scatterplot(x='yrs.since.phd',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='salary'>

# %%
sns.scatterplot(x='yrs.service',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='salary'>

# %%
sns.scatterplot(x='sex',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='salary'>

# %%
sns.scatterplot(x='salary',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='salary'>

# %%
df.corr()
# Out:
#                yrs.since.phd  yrs.service    salary
# yrs.since.phd       1.000000     0.909649  0.419231
# yrs.service         0.909649     1.000000  0.334745
# salary              0.419231     0.334745  1.000000

# %%
df.corr()['salary'].sort_values()
# Out:
# yrs.service      0.334745
# yrs.since.phd    0.419231
# salary           1.000000
# Name: salary, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("variable summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.skew()
# Out:
# yrs.since.phd    0.300880
# yrs.service      0.650569
# salary           0.714568
# dtype: float64

# %%
sns.distplot(df["yrs.since.phd"])
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='Density'>

# %%
sns.distplot(df["yrs.service"])
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='Density'>

# %%
sns.distplot(df["salary"])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
df.corr()['salary']
# Out:
# yrs.since.phd    0.419231
# yrs.service      0.334745
# salary           1.000000
# Name: salary, dtype: float64

# %%
delete=pd.DataFrame([["-0.521999","yrs.since.phd","No","Alot"],["0.530474","yrs.service","No","Alot"]],columns=["correlation with Target","column Name","Normalised","Outlier"])
delete
# Out:
#   correlation with Target    column Name Normalised Outlier
# 0               -0.521999  yrs.since.phd         No    Alot
# 1                0.530474    yrs.service         No    Alot

# %%
df=df.drop(["yrs.since.phd","yrs.service"],axis=1)

# %%
df
# Out:
#          rank discipline   sex  salary
# 0        Prof          B  Male  139750
# 1        Prof          B  Male  173200
# 2    AsstProf          B  Male   79750
# 3        Prof          B  Male  115000
# 4        Prof          B  Male  141500
# ..        ...        ...   ...     ...
# 392      Prof          A  Male  103106
# 393      Prof          A  Male  150564
# 394      Prof          A  Male  101738
# 395      Prof          A  Male   95329
# 396  AsstProf          A  Male   81035
#
# [397 rows x 4 columns]
